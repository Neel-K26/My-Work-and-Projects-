# %%
#CNN for Image Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequentials
from tensorflow.keras.layers import Dense,Conv2D, MaxPool2d
from tensorflow.keras.layers import Flatten,Dropout
from tensorflow.keras.dataset import mnist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8860/3404123371.py in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from tensorflow.keras.models import Sequentials
#       4 from tensorflow.keras.layers import Dense,Conv2D, MaxPool2d
#       5 from tensorflow.keras.layers import Flatten,Dropout
#
# ~\anaconda3\lib\site-packages\keras\api\_v2\keras\__init__.py in <module>
#      10 import sys as _sys
#      11
# ---> 12 from keras import __version__
#      13 from keras.api._v2.keras import __internal__
#      14 from keras.api._v2.keras import activations
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#      22 from keras import distribute
#      23
# ---> 24 from keras import models
#      25
#      26 from keras.engine.input_layer import Input
#
# ~\anaconda3\lib\site-packages\keras\models\__init__.py in <module>
#      16 # pylint: disable=g-bad-import-order
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# ~\anaconda3\lib\site-packages\keras\engine\functional.py in <module>
#      22 import warnings
#      23 from keras import backend
# ---> 24 from keras.dtensor import layout_map as layout_map_lib
#      25 from keras.engine import base_layer
#      26 from keras.engine import base_layer_utils
#
# ~\anaconda3\lib\site-packages\keras\dtensor\__init__.py in <module>
#      20 # Conditional import the dtensor API, since it is currently broken in OSS.
#      21 if _DTENSOR_API_ENABLED:
# ---> 22   from tensorflow.compat.v2.experimental import dtensor as dtensor_api  # pylint: disable=g-import-not-at-top
#      23 else:
#      24   # Leave it with a placeholder, so that the import line from other python file
#
# ~\anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v2\experimental\dtensor\__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow.dtensor.python.api import call_with_layout
#       9 from tensorflow.dtensor.python.api import check_layout
#      10 from tensorflow.dtensor.python.api import client_id
#
# ~\anaconda3\lib\site-packages\tensorflow\dtensor\python\__init__.py in <module>
#      15 """DTensor Python API."""
#      16
# ---> 17 from tensorflow.dtensor.python import gen_dtensor_ops as ops
#      18 from tensorflow.dtensor.python import mesh_util
#      19 from tensorflow.dtensor.python import tpu_util
#
# ~\anaconda3\lib\site-packages\tensorflow\dtensor\python\gen_dtensor_ops.py in <module>
#      21 from typing import TypeVar
#      22
# ---> 23 @_dispatch.add_fallback_dispatch_list
#      24 @_dispatch.add_type_based_api_dispatcher
#      25 @tf_export('configure_and_initialize_global_tpu')
#
# AttributeError: module 'tensorflow.python.util.dispatch' has no attribute 'add_fallback_dispatch_list'
