# %%
# Graph Plotting with matplotlib 😖
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.array([0,10])
y= np.array([0,300])

# %%
x
# Out:
# array([ 0, 10])

# %%
y
# Out:
# array([  0, 300])

# %%
plt.xlabel("Freq") 
plt.ylabel("Count")
plt.plot(x,y,'o') # defining shapes
plt.show()

# %%
# labels
x=np.array([1,2,3,4,5,6,7,8])
y=np.array([2,4,6,8,10,12,14,16])
x.shape
y.shape
plt.plot(x,y,'o')

# %%
#marker
y=np.array([23,45,56,78,80,87])
plt.plot(y,marker='o',color='red')
plt.plot(y,'o:r')

# %%
plt.plot(y,'*:b',ms=15)  #(axis,symbol:color,markersize)

# %%
plt.bar([0.25,0.50,0.60,1.0],[20,30,10,40],label='population',color='b',width = 0.1)
plt.xlabel('percentage ')
plt.ylabel('frequency ')
# Out:
# Text(0, 0.5, 'frequency ')

# %%
# Histogram
age=[12,13,32,45,22,23,33]
bins=[0,10,30,40,100] # limit of axis genrally
plt.hist(age,bins=bins,histtype='bar',rwidth=0.9)
# Out:
# (array([0., 4., 2., 1.]),
#  array([  0,  10,  30,  40, 100]),
#  <BarContainer object of 4 artists>)

# %%
# Scatter
x =np.array([1,2,3,4,5,6,7,8])
y =np.array([8,7,6,5,4,3,2,1])
z=np.array([12,23,34,46,52,66,78,83])
plt.xlabel('weight')
plt.ylabel("spped")
plt.scatter(weight,speed)
# Negative Co-relation

# %%
# stackplot
plt.plot([],[],color='b',label=x,linewidth=5)
plt.plot([],[],color='g',label=y,linewidth=5)
plt.stackplot(x,y,z,colors='c,g')

# %%
# PIE CHART (%tages) genrally of 100 % as total
sales=[13,23,19,45]

# %%
dept=['IT','TECH','HR','ADMIN']

# %%
c=['c','g','b','m']

# %%
plt.pie(sales,labels=dept,colors=c)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f10858b1f0>,
# ...
#  [Text(1.009530094796705, 0.43686266457521417, 'IT'),
#   Text(0.034551853514891685, 1.0994572158200089, 'TECH'),
#   Text(-1.056323050796661, 0.30689022851116443, 'HR'),
#   Text(0.17207785051137656, -1.086457184321308, 'ADMIN')])
