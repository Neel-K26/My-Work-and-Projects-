# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=num_line = np.linspace(10,25,20)
y=num_line = np.linspace(1,21,20)
plt.ylim(1,21)
plt.title("Linear GRAPH")
plt.ylabel(" Elements Axis")
plt.xlabel("Linear Spaced Axis")
plt.plot(x,y)

# %%
import numpy as np
num_line = np.linspace(10,25,20)

print(num_line)
# Out:
# [10.         10.78947368 11.57894737 12.36842105 13.15789474 13.94736842
#  14.73684211 15.52631579 16.31578947 17.10526316 17.89473684 18.68421053
#  19.47368421 20.26315789 21.05263158 21.84210526 22.63157895 23.42105263
#  24.21052632 25.        ]

# %%
from scipy import signal
import matplotlib.pyplot as plot
import numpy as np

t = np.linspace(0, 1, 100, endpoint=True)
	
# Plot the square wave
plot.plot(t, signal.square(2 * np.pi * 5 * t))

# Give x,y,title axis label
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.title('Square wave - Geeksforgeeks')

plot.axhline(y = 0, color = 'k')

# Display
plot.show()

# %%
x = [12,34,54,34,67,68,59,89,92,44]
y = [11,19,26,37,58,69,88,103,111,128]
t = [2,4,8,12,22,44,68,70,100,120]
plt.xlabel('X side')
plt.ylabel('Y side')
plt.plot(x,y,color='g',marker='.')
plt.plot(x,t,color='b',marker='*')

# %%
#plotting the subplot
plt.subplot(2,1,1,facecolor='yellow')
plt.plot(x,y,color='g',marker='.')
plt.subplot(2,1,2,facecolor='lightblue',)
plt.plot(x,t,color='b',marker='*')

# %%
#Printing Histogram
import numpy as np
a=np.array([18,23,45,11,67,334,126,74,34,102,33,199,218,111,17,178,123,2,45,45,56])
plt.hist(a,bins=[0,20,40,60,80,100])
# Out:
# (array([4., 3., 4., 2., 0.]),
#  array([  0,  20,  40,  60,  80, 100]),
#  <BarContainer object of 5 artists>)

# %%
import matplotlib.pyplot as plt
# line 1 points
x1 = [10,20,30]
y1 = [20,40,10]
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1",linestyle='--')
# line 2 points
x2 = [10,20,30]
y2 = [40,10,30]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2",linestyle=':',color='red')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line designed output ')
plt.legend()
plt.show()

# %%
#
plt.subplot(2,1,1,facecolor='lightblue')
plt.plot(x,y,color="r",linestyle='-.')
plt.subplot(2,2,3,facecolor='lightblue')
plt.plot(x,y,color="g",marker='.')
plt.subplot(2,2,4,facecolor='lightblue')
plt.plot(x,y,color="g",marker='.')
